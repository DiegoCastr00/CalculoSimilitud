# %%
import pandas as pd

def extract_painting_name(filename):
    """
    Extrae el nombre de la pintura del nombre del archivo
    (la parte entre el primer guion bajo y _resize1024.jpg después del último /)
    """
    try:
        file_part = filename.split('/')[-1]
        parts = file_part.split('_')
        if len(parts) >= 2:
            painting_name = parts[1]
            if painting_name in ["arnold-bocklin", "arnold-bocklin"]:
                painting_name = "pan-" + painting_name
            return painting_name  # Retorna la parte del nombre de la pintura
    except:
        return None
    return None

def merge_csv_files(metadata_blip2_path, dataset_path):
    """
    Combina dos archivos CSV usando el nombre de la pintura como clave
    y mantiene la descripción BLIP2 de metadata_blip2.csv
    """
    blip2_df = pd.read_csv(metadata_blip2_path)
    dataset_df = pd.read_csv(dataset_path)

    blip2_df['match'] = blip2_df['file_name'].apply(extract_painting_name)
    dataset_df['match'] = dataset_df['file_name'].apply(extract_painting_name)
    result_df = dataset_df.copy()

    blip2_dict = dict(zip(blip2_df['match'], blip2_df['blip2']))

    unmatched_files = []

    def update_description(row):
        if row['match'] in blip2_dict:
            return blip2_dict[row['match']]
        else:
            unmatched_files.append(row['file_name'])
            return row.get('description', '')

    result_df['description'] = result_df.apply(update_description, axis=1)

    result_df = result_df.drop('match', axis=1)
    result_df = result_df.drop('paint_name.1', axis=1)

    result_df = result_df.loc[:, ~result_df.columns.duplicated()]

    if unmatched_files:
        print("\nArchivos sin coincidencia encontrada:")
        for file in unmatched_files:
            print(f"- {file}")

    # Imprimir estadísticas
    total_files = len(result_df)
    matched_files = total_files - len(unmatched_files)
    print(f"\nEstadísticas:")
    print(f"Total de archivos procesados: {total_files}")
    print(f"Archivos con coincidencia: {matched_files}")
    print(f"Archivos sin coincidencia: {len(unmatched_files)}")

    # Renombrar la columna paint_name a painting_name
    result_df = result_df.rename(columns={'paint_name': 'painting_name'})

    # Reordenar las columnas
    result_df = result_df[['file_name', 'genre', 'artist', 'painting_name', 'phash', 'description', 'subset']]

    return result_df

# Ejemplo de uso
metadata_blip2_path = 'metadata_blip2.csv'
dataset_path = 'newName.csv'

resultado = merge_csv_files(metadata_blip2_path, dataset_path)
# Out:
# Estadísticas:
# Total de archivos procesados: 81444
# Archivos con coincidencia: 81444
# Archivos sin coincidencia: 0

# %%
resultado
# Out:
#                                                file_name               genre  \
# 0      Impressionism/william-merritt-chase_still-life...       Impressionism
# 1      Expressionism/pablo-picasso_study-to-two-siste...       Expressionism
# 2      Post_Impressionism/pyotr-konchalovsky_dry-pain...  Post Impressionism
# 3      High_Renaissance/pietro-perugino_madonna-with-...    High Renaissance
# 4      Realism/john-everett-millais_portrait-of-mrs-j...             Realism
# ...                                                  ...                 ...
# 81439  Early_Renaissance/carlo-crivelli_saint-john-th...   Early Renaissance
# 81440      Realism/robert-brackman_pastel_resize1024.jpg             Realism
# 81441  Impressionism/kazimir-malevich_spring-landscap...       Impressionism
# 81442  Fauvism/ion-pacea_marina-with-yellow-boat_resi...             Fauvism
# 81443  Impressionism/camille-pissarro_harvest-at-erag...       Impressionism
#
#                       artist                          painting_name  \
# 0      william merritt chase               still life with cockatoo
# 1              pablo picasso              study to two sisters 1902
# 2         pyotr konchalovsky                        dry paints 1913
# 3            pietro perugino  madonna with child and little st john
# 4       john everett millais            portrait of mrs james wyatt
# ...                      ...                                    ...
# 81439         carlo crivelli              saint john the evangelist
# 81440        robert brackman                                 pastel
# 81441       kazimir malevich                       spring landscape
# 81442              ion pacea                marina with yellow boat
# 81443       camille pissarro                 harvest at eragny 1901
#
#                   phash                                        description  \
# 0      b0e24b85961e6de9      a painting of a white bird sitting on a vase
# 1      a73452d3366e86c9      a drawing of two people embracing each other
# 2      d1512e3c94a7d1e3    a painting of a table with various items on it
# 3      dab3114c64cae72d  madonna and child with two children by luigi d...
# 4      9bd1e4acd211ad4b             a painting of a woman holding a child
# ...                 ...                                                ...
# 81439  aef969b1c224f283                a painting of a man holding a book
# 81440  edc5961bb2199a26     a drawing of a naked woman sitting on a towel
# 81441  d1d096ab5be2926a         a painting of trees in a field with grass
# 81442  c0fe2f2d10402fbf  a painting of boats in the water with a blue sky
# 81443  93325ac94b31cdd9       the women are working in the field with hay
#
#       subset
# 0      train
# 1      train
# 2      train
# 3      train
# 4      train
# ...      ...
# 81439   test
# 81440   test
# 81441   test
# 81442   test
# 81443   test
#
# [81444 rows x 7 columns]

# %%
import os


image_base_path = 'imagenes/resizeSD'
missing_images = []

for index, row in resultado.iterrows():
    image_path = os.path.join(image_base_path, row['file_name'])
    if not os.path.exists(image_path):
        missing_images.append(row['file_name'])


if missing_images:
    print("Imágenes faltantes:")
    print("\n".join(missing_images))
else:
    print("Todas las imágenes existen.")
# Out:
# Todas las imágenes existen.

# %%
resultado.to_csv("dataset.csv", index=False)
