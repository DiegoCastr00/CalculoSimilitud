# %%
import pandas as pd
import numpy as np
import random

csv1_path = "data.csv"  
csv2_path = "data_blip2SDXL.csv"  

df1 = pd.read_csv(csv1_path)
df2 = pd.read_csv(csv2_path)

# Paso 1: Filtrar las columnas necesarias
df1 = df1[['file_name', 'description']]
df2 = df2[['file_name', 'blip2']]

# Paso 2: Normalizar los nombres de archivo en el segundo CSV
df2['file_name'] = df2['file_name'].str.replace('_generated', '', regex=False)

# Paso 3: Hacer el match usando un merge OUTER para identificar registros sin coincidencia
merged_df = pd.merge(df1, df2, on='file_name', how='outer', indicator=True)

# Paso 4: Identificar registros sin coincidencia
df1_only = merged_df[merged_df['_merge'] == 'left_only']
df2_only = merged_df[merged_df['_merge'] == 'right_only']

print(f"Registros en el primer CSV sin coincidencia en el segundo CSV: {len(df1_only)}")
print(f"Registros en el segundo CSV sin coincidencia en el primer CSV: {len(df2_only)}")

if len(df1_only) > 0:
    print("Registros únicos en el primer CSV:")
    print(df1_only[['file_name']])

if len(df2_only) > 0:
    print("Registros únicos en el segundo CSV:")
    print(df2_only[['file_name']])

# Paso 5: Procesar solo los registros que tienen coincidencia (inner merge)
matched_df = pd.merge(df1, df2, on='file_name', how='inner')

# Paso 6: Extraer el género (carpeta) de cada file_name
matched_df['genre'] = matched_df['file_name'].apply(lambda x: x.split('/')[0] if '/' in x else "unknown")

# Paso 7: Generar las columnas requeridas para imágenes originales y generadas
matched_df['original_image'] = 'resize768/' + matched_df['file_name']
matched_df['generated_image'] = 'SDXL/' + matched_df['file_name'].str.replace('.jpg', '_generated.jpg', regex=False)
matched_df['description_original_image'] = matched_df['description']
matched_df['description_generated_image'] = matched_df['blip2']

# Paso 8: Crear un diccionario para organizar las filas por género
genre_dict = {}
for genre in matched_df['genre'].unique():
    genre_dict[genre] = matched_df[matched_df['genre'] == genre].index.tolist()

# Paso 9: Seleccionar aleatoriamente imágenes negativas de diferentes géneros sin repetir
df1_copy = df1.copy()
df1_copy['genre'] = df1_copy['file_name'].apply(lambda x: x.split('/')[0] if '/' in x else "unknown")

matched_df['negative_image'] = None
matched_df['description_negative_image'] = None

# Conjunto para rastrear imágenes negativas ya utilizadas
used_negative_images = set()

# Para cada fila en matched_df
for idx, row in matched_df.iterrows():
    current_genre = row['genre']
    
    # Encontrar todos los géneros diferentes al actual
    other_genres = [g for g in genre_dict.keys() if g != current_genre]
    
    # Si no hay otros géneros disponibles, usar cualquier género (caso improbable)
    if not other_genres:
        other_genres = list(genre_dict.keys())
    
    # Seleccionar aleatoriamente un género diferente
    random_genre = random.choice(other_genres)
    
    # Intentar encontrar una imagen no utilizada
    potential_indices = [i for i in genre_dict[random_genre] if i not in used_negative_images]
    
    # Si no hay imágenes disponibles en este género, intentar con otro
    attempts = 0
    while not potential_indices and attempts < len(other_genres):
        random_genre = random.choice(other_genres)
        potential_indices = [i for i in genre_dict[random_genre] if i not in used_negative_images]
        attempts += 1
    
    # Si todavía no tenemos opciones, usar cualquiera que no haya sido usada
    if not potential_indices:
        all_unused = [i for i in range(len(matched_df)) if i not in used_negative_images and i != idx]
        if all_unused:
            selected_idx = random.choice(all_unused)
        else:
            # Si todas han sido usadas, simplemente elegir una diferente a la actual
            all_other = [i for i in range(len(matched_df)) if i != idx]
            selected_idx = random.choice(all_other) if all_other else 0
    else:
        selected_idx = random.choice(potential_indices)
    
    # Marcar esta imagen como utilizada
    used_negative_images.add(selected_idx)
    
    # Asignar la imagen negativa y su descripción
    neg_file_name = matched_df.iloc[selected_idx]['file_name']
    matched_df.at[idx, 'negative_image'] = 'resize768/' + neg_file_name
    
    # Buscar la descripción original en df1_copy
    neg_description = df1_copy[df1_copy['file_name'] == neg_file_name]['description'].values[0]
    matched_df.at[idx, 'description_negative_image'] = neg_description

# Paso 10: Seleccionar solo las columnas finales requeridas
result_df = matched_df[['original_image', 'generated_image', 'negative_image', 
                         'description_original_image', 'description_generated_image', 'description_negative_image']]

# Guardar el resultado en un nuevo CSV
output_path = "archivo_resultado_con_negativas.csv"
result_df.to_csv(output_path, index=False)
print("Proceso completado. El archivo resultante se ha guardado en:", output_path)
# Out:
# Registros en el primer CSV sin coincidencia en el segundo CSV: 0
# Registros en el segundo CSV sin coincidencia en el primer CSV: 0
# Proceso completado. El archivo resultante se ha guardado en: archivo_resultado_con_negativas.csv

# %%
import pandas as pd
import os
from config import Config
csv_path = "data.csv"
base_folder = Config.IMAGES_DIR
df = pd.read_csv(csv_path)

missing_original = []
missing_generated = []
missing_negative = []

total_rows = len(df)
print(f"Verificando {total_rows} filas de imágenes...")

for idx, row in df.iterrows():
    original_path = os.path.join(base_folder, row['original_image'])
    generated_path = os.path.join(base_folder, row['generated_image'])
    negative_path = os.path.join(base_folder, row['negative_image'])
    
    if not os.path.isfile(original_path):
        missing_original.append(original_path)
    
    if not os.path.isfile(generated_path):
        missing_generated.append(generated_path)
    
    if not os.path.isfile(negative_path):
        missing_negative.append(negative_path)
    
    if (idx + 1) % 100 == 0:
        print(f"Procesadas {idx + 1}/{total_rows} filas...")

print("\n--- RESULTADOS DE LA VERIFICACIÓN ---")
print(f"Total de imágenes originales no encontradas: {len(missing_original)}")
print(f"Total de imágenes generadas no encontradas: {len(missing_generated)}")
print(f"Total de imágenes negativas no encontradas: {len(missing_negative)}")

if missing_original:
    print("\nImágenes originales no encontradas:")
    for path in missing_original:
        print(f"- {path}")

if missing_generated:
    print("\nImágenes generadas no encontradas:")
    for path in missing_generated:
        print(f"- {path}")

if missing_negative:
    print("\nImágenes negativas no encontradas:")
    for path in missing_negative:
        print(f"- {path}")
# Out:
# Verificando 81444 filas de imágenes...
# Procesadas 100/81444 filas...
# Procesadas 200/81444 filas...
# Procesadas 300/81444 filas...
# Procesadas 400/81444 filas...
# Procesadas 500/81444 filas...
# Procesadas 600/81444 filas...
# Procesadas 700/81444 filas...
# Procesadas 800/81444 filas...
# Procesadas 900/81444 filas...
# Procesadas 1000/81444 filas...
# Procesadas 1100/81444 filas...
# Procesadas 1200/81444 filas...
# Procesadas 1300/81444 filas...
# Procesadas 1400/81444 filas...
# Procesadas 1500/81444 filas...
# Procesadas 1600/81444 filas...
# Procesadas 1700/81444 filas...
# Procesadas 1800/81444 filas...
# Procesadas 1900/81444 filas...
# Procesadas 2000/81444 filas...
# Procesadas 2100/81444 filas...
# Procesadas 2200/81444 filas...
# Procesadas 2300/81444 filas...
# Procesadas 2400/81444 filas...
# Procesadas 2500/81444 filas...
# Procesadas 2600/81444 filas...
# Procesadas 2700/81444 filas...
# Procesadas 2800/81444 filas...
# Procesadas 2900/81444 filas...
# Procesadas 3000/81444 filas...
# Procesadas 3100/81444 filas...
# Procesadas 3200/81444 filas...
# Procesadas 3300/81444 filas...
# Procesadas 3400/81444 filas...
# Procesadas 3500/81444 filas...
# Procesadas 3600/81444 filas...
# Procesadas 3700/81444 filas...
# Procesadas 3800/81444 filas...
# Procesadas 3900/81444 filas...
# Procesadas 4000/81444 filas...
# Procesadas 4100/81444 filas...
# Procesadas 4200/81444 filas...
# Procesadas 4300/81444 filas...
# Procesadas 4400/81444 filas...
# Procesadas 4500/81444 filas...
# Procesadas 4600/81444 filas...
# Procesadas 4700/81444 filas...
# Procesadas 4800/81444 filas...
# Procesadas 4900/81444 filas...
# Procesadas 5000/81444 filas...
# Procesadas 5100/81444 filas...
# Procesadas 5200/81444 filas...
# Procesadas 5300/81444 filas...
# Procesadas 5400/81444 filas...
# Procesadas 5500/81444 filas...
# Procesadas 5600/81444 filas...
# Procesadas 5700/81444 filas...
# Procesadas 5800/81444 filas...
# Procesadas 5900/81444 filas...
# Procesadas 6000/81444 filas...
# Procesadas 6100/81444 filas...
# Procesadas 6200/81444 filas...
# Procesadas 6300/81444 filas...
# Procesadas 6400/81444 filas...
# Procesadas 6500/81444 filas...
# Procesadas 6600/81444 filas...
# Procesadas 6700/81444 filas...
# Procesadas 6800/81444 filas...
# Procesadas 6900/81444 filas...
# Procesadas 7000/81444 filas...
# Procesadas 7100/81444 filas...
# Procesadas 7200/81444 filas...
# Procesadas 7300/81444 filas...
# Procesadas 7400/81444 filas...
# Procesadas 7500/81444 filas...
# Procesadas 7600/81444 filas...
# Procesadas 7700/81444 filas...
# Procesadas 7800/81444 filas...
# Procesadas 7900/81444 filas...
# Procesadas 8000/81444 filas...
# Procesadas 8100/81444 filas...
# Procesadas 8200/81444 filas...
# Procesadas 8300/81444 filas...
# Procesadas 8400/81444 filas...
# Procesadas 8500/81444 filas...
# Procesadas 8600/81444 filas...
# Procesadas 8700/81444 filas...
# Procesadas 8800/81444 filas...
# Procesadas 8900/81444 filas...
# Procesadas 9000/81444 filas...
# Procesadas 9100/81444 filas...
# Procesadas 9200/81444 filas...
# Procesadas 9300/81444 filas...
# Procesadas 9400/81444 filas...
# Procesadas 9500/81444 filas...
# Procesadas 9600/81444 filas...
# Procesadas 9700/81444 filas...
# Procesadas 9800/81444 filas...
# Procesadas 9900/81444 filas...
# Procesadas 10000/81444 filas...
# Procesadas 10100/81444 filas...
# Procesadas 10200/81444 filas...
# Procesadas 10300/81444 filas...
# Procesadas 10400/81444 filas...
# Procesadas 10500/81444 filas...
# Procesadas 10600/81444 filas...
# Procesadas 10700/81444 filas...
# Procesadas 10800/81444 filas...
# Procesadas 10900/81444 filas...
# Procesadas 11000/81444 filas...
# Procesadas 11100/81444 filas...
# Procesadas 11200/81444 filas...
# Procesadas 11300/81444 filas...
# Procesadas 11400/81444 filas...
# Procesadas 11500/81444 filas...
# Procesadas 11600/81444 filas...
# Procesadas 11700/81444 filas...
# Procesadas 11800/81444 filas...
# Procesadas 11900/81444 filas...
# Procesadas 12000/81444 filas...
# Procesadas 12100/81444 filas...
# Procesadas 12200/81444 filas...
# Procesadas 12300/81444 filas...
# Procesadas 12400/81444 filas...
# Procesadas 12500/81444 filas...
# Procesadas 12600/81444 filas...
# Procesadas 12700/81444 filas...
# Procesadas 12800/81444 filas...
# Procesadas 12900/81444 filas...
# Procesadas 13000/81444 filas...
# Procesadas 13100/81444 filas...
# Procesadas 13200/81444 filas...
# Procesadas 13300/81444 filas...
# Procesadas 13400/81444 filas...
# Procesadas 13500/81444 filas...
# Procesadas 13600/81444 filas...
# Procesadas 13700/81444 filas...
# Procesadas 13800/81444 filas...
# Procesadas 13900/81444 filas...
# Procesadas 14000/81444 filas...
# Procesadas 14100/81444 filas...
# Procesadas 14200/81444 filas...
# Procesadas 14300/81444 filas...
# Procesadas 14400/81444 filas...
# Procesadas 14500/81444 filas...
# Procesadas 14600/81444 filas...
# Procesadas 14700/81444 filas...
# Procesadas 14800/81444 filas...
# Procesadas 14900/81444 filas...
# Procesadas 15000/81444 filas...
# Procesadas 15100/81444 filas...
# Procesadas 15200/81444 filas...
# Procesadas 15300/81444 filas...
# Procesadas 15400/81444 filas...
# Procesadas 15500/81444 filas...
# Procesadas 15600/81444 filas...
# Procesadas 15700/81444 filas...
# Procesadas 15800/81444 filas...
# Procesadas 15900/81444 filas...
# Procesadas 16000/81444 filas...
# Procesadas 16100/81444 filas...
# Procesadas 16200/81444 filas...
# Procesadas 16300/81444 filas...
# Procesadas 16400/81444 filas...
# Procesadas 16500/81444 filas...
# Procesadas 16600/81444 filas...
# Procesadas 16700/81444 filas...
# Procesadas 16800/81444 filas...
# Procesadas 16900/81444 filas...
# Procesadas 17000/81444 filas...
# Procesadas 17100/81444 filas...
# Procesadas 17200/81444 filas...
# Procesadas 17300/81444 filas...
# Procesadas 17400/81444 filas...
# Procesadas 17500/81444 filas...
# Procesadas 17600/81444 filas...
# Procesadas 17700/81444 filas...
# Procesadas 17800/81444 filas...
# Procesadas 17900/81444 filas...
# Procesadas 18000/81444 filas...
# Procesadas 18100/81444 filas...
# Procesadas 18200/81444 filas...
# Procesadas 18300/81444 filas...
# Procesadas 18400/81444 filas...
# Procesadas 18500/81444 filas...
# Procesadas 18600/81444 filas...
# Procesadas 18700/81444 filas...
# Procesadas 18800/81444 filas...
# Procesadas 18900/81444 filas...
# Procesadas 19000/81444 filas...
# Procesadas 19100/81444 filas...
# Procesadas 19200/81444 filas...
# Procesadas 19300/81444 filas...
# Procesadas 19400/81444 filas...
# Procesadas 19500/81444 filas...
# Procesadas 19600/81444 filas...
# Procesadas 19700/81444 filas...
# Procesadas 19800/81444 filas...
# Procesadas 19900/81444 filas...
# Procesadas 20000/81444 filas...
# Procesadas 20100/81444 filas...
# Procesadas 20200/81444 filas...
# Procesadas 20300/81444 filas...
# Procesadas 20400/81444 filas...
# Procesadas 20500/81444 filas...
# Procesadas 20600/81444 filas...
# Procesadas 20700/81444 filas...
# Procesadas 20800/81444 filas...
# Procesadas 20900/81444 filas...
# Procesadas 21000/81444 filas...
# Procesadas 21100/81444 filas...
# Procesadas 21200/81444 filas...
# Procesadas 21300/81444 filas...
# Procesadas 21400/81444 filas...
# Procesadas 21500/81444 filas...
# Procesadas 21600/81444 filas...
# Procesadas 21700/81444 filas...
# Procesadas 21800/81444 filas...
# Procesadas 21900/81444 filas...
# Procesadas 22000/81444 filas...
# Procesadas 22100/81444 filas...
# Procesadas 22200/81444 filas...
# Procesadas 22300/81444 filas...
# Procesadas 22400/81444 filas...
# Procesadas 22500/81444 filas...
# Procesadas 22600/81444 filas...
# Procesadas 22700/81444 filas...
# Procesadas 22800/81444 filas...
# Procesadas 22900/81444 filas...
# Procesadas 23000/81444 filas...
# Procesadas 23100/81444 filas...
# Procesadas 23200/81444 filas...
# Procesadas 23300/81444 filas...
# Procesadas 23400/81444 filas...
# Procesadas 23500/81444 filas...
# Procesadas 23600/81444 filas...
# Procesadas 23700/81444 filas...
# Procesadas 23800/81444 filas...
# Procesadas 23900/81444 filas...
# Procesadas 24000/81444 filas...
# Procesadas 24100/81444 filas...
# Procesadas 24200/81444 filas...
# Procesadas 24300/81444 filas...
# Procesadas 24400/81444 filas...
# Procesadas 24500/81444 filas...
# Procesadas 24600/81444 filas...
# Procesadas 24700/81444 filas...
# Procesadas 24800/81444 filas...
# Procesadas 24900/81444 filas...
# Procesadas 25000/81444 filas...
# Procesadas 25100/81444 filas...
# Procesadas 25200/81444 filas...
# Procesadas 25300/81444 filas...
# Procesadas 25400/81444 filas...
# Procesadas 25500/81444 filas...
# Procesadas 25600/81444 filas...
# Procesadas 25700/81444 filas...
# Procesadas 25800/81444 filas...
# Procesadas 25900/81444 filas...
# Procesadas 26000/81444 filas...
# Procesadas 26100/81444 filas...
# Procesadas 26200/81444 filas...
# Procesadas 26300/81444 filas...
# Procesadas 26400/81444 filas...
# Procesadas 26500/81444 filas...
# Procesadas 26600/81444 filas...
# Procesadas 26700/81444 filas...
# Procesadas 26800/81444 filas...
# Procesadas 26900/81444 filas...
# Procesadas 27000/81444 filas...
# Procesadas 27100/81444 filas...
# Procesadas 27200/81444 filas...
# Procesadas 27300/81444 filas...
# Procesadas 27400/81444 filas...
# Procesadas 27500/81444 filas...
# Procesadas 27600/81444 filas...
# Procesadas 27700/81444 filas...
# Procesadas 27800/81444 filas...
# Procesadas 27900/81444 filas...
# Procesadas 28000/81444 filas...
# Procesadas 28100/81444 filas...
# Procesadas 28200/81444 filas...
# Procesadas 28300/81444 filas...
# Procesadas 28400/81444 filas...
# Procesadas 28500/81444 filas...
# Procesadas 28600/81444 filas...
# Procesadas 28700/81444 filas...
# Procesadas 28800/81444 filas...
# Procesadas 28900/81444 filas...
# Procesadas 29000/81444 filas...
# Procesadas 29100/81444 filas...
# Procesadas 29200/81444 filas...
# Procesadas 29300/81444 filas...
# Procesadas 29400/81444 filas...
# Procesadas 29500/81444 filas...
# Procesadas 29600/81444 filas...
# Procesadas 29700/81444 filas...
# Procesadas 29800/81444 filas...
# Procesadas 29900/81444 filas...
# Procesadas 30000/81444 filas...
# Procesadas 30100/81444 filas...
# Procesadas 30200/81444 filas...
# Procesadas 30300/81444 filas...
# Procesadas 30400/81444 filas...
# Procesadas 30500/81444 filas...
# Procesadas 30600/81444 filas...
# Procesadas 30700/81444 filas...
# Procesadas 30800/81444 filas...
# Procesadas 30900/81444 filas...
# Procesadas 31000/81444 filas...
# Procesadas 31100/81444 filas...
# Procesadas 31200/81444 filas...
# Procesadas 31300/81444 filas...
# Procesadas 31400/81444 filas...
# Procesadas 31500/81444 filas...
# Procesadas 31600/81444 filas...
# Procesadas 31700/81444 filas...
# Procesadas 31800/81444 filas...
# Procesadas 31900/81444 filas...
# Procesadas 32000/81444 filas...
# Procesadas 32100/81444 filas...
# Procesadas 32200/81444 filas...
# Procesadas 32300/81444 filas...
# Procesadas 32400/81444 filas...
# Procesadas 32500/81444 filas...
# Procesadas 32600/81444 filas...
# Procesadas 32700/81444 filas...
# Procesadas 32800/81444 filas...
# Procesadas 32900/81444 filas...
# Procesadas 33000/81444 filas...
# Procesadas 33100/81444 filas...
# Procesadas 33200/81444 filas...
# Procesadas 33300/81444 filas...
# Procesadas 33400/81444 filas...
# Procesadas 33500/81444 filas...
# Procesadas 33600/81444 filas...
# Procesadas 33700/81444 filas...
# Procesadas 33800/81444 filas...
# Procesadas 33900/81444 filas...
# Procesadas 34000/81444 filas...
# Procesadas 34100/81444 filas...
# Procesadas 34200/81444 filas...
# Procesadas 34300/81444 filas...
# Procesadas 34400/81444 filas...
# Procesadas 34500/81444 filas...
# Procesadas 34600/81444 filas...
# Procesadas 34700/81444 filas...
# Procesadas 34800/81444 filas...
# Procesadas 34900/81444 filas...
# Procesadas 35000/81444 filas...
# Procesadas 35100/81444 filas...
# Procesadas 35200/81444 filas...
# Procesadas 35300/81444 filas...
# Procesadas 35400/81444 filas...
# Procesadas 35500/81444 filas...
# Procesadas 35600/81444 filas...
# Procesadas 35700/81444 filas...
# Procesadas 35800/81444 filas...
# Procesadas 35900/81444 filas...
# Procesadas 36000/81444 filas...
# Procesadas 36100/81444 filas...
# Procesadas 36200/81444 filas...
# Procesadas 36300/81444 filas...
# Procesadas 36400/81444 filas...
# Procesadas 36500/81444 filas...
# Procesadas 36600/81444 filas...
# Procesadas 36700/81444 filas...
# Procesadas 36800/81444 filas...
# Procesadas 36900/81444 filas...
# Procesadas 37000/81444 filas...
# Procesadas 37100/81444 filas...
# Procesadas 37200/81444 filas...
# Procesadas 37300/81444 filas...
# Procesadas 37400/81444 filas...
# Procesadas 37500/81444 filas...
# Procesadas 37600/81444 filas...
# Procesadas 37700/81444 filas...
# Procesadas 37800/81444 filas...
# Procesadas 37900/81444 filas...
# Procesadas 38000/81444 filas...
# Procesadas 38100/81444 filas...
# Procesadas 38200/81444 filas...
# Procesadas 38300/81444 filas...
# Procesadas 38400/81444 filas...
# Procesadas 38500/81444 filas...
# Procesadas 38600/81444 filas...
# Procesadas 38700/81444 filas...
# Procesadas 38800/81444 filas...
# Procesadas 38900/81444 filas...
# Procesadas 39000/81444 filas...
# Procesadas 39100/81444 filas...
# Procesadas 39200/81444 filas...
# Procesadas 39300/81444 filas...
# Procesadas 39400/81444 filas...
# Procesadas 39500/81444 filas...
# Procesadas 39600/81444 filas...
# Procesadas 39700/81444 filas...
# Procesadas 39800/81444 filas...
# Procesadas 39900/81444 filas...
# Procesadas 40000/81444 filas...
# Procesadas 40100/81444 filas...
# Procesadas 40200/81444 filas...
# Procesadas 40300/81444 filas...
# Procesadas 40400/81444 filas...
# Procesadas 40500/81444 filas...
# Procesadas 40600/81444 filas...
# Procesadas 40700/81444 filas...
# Procesadas 40800/81444 filas...
# Procesadas 40900/81444 filas...
# Procesadas 41000/81444 filas...
# Procesadas 41100/81444 filas...
# Procesadas 41200/81444 filas...
# Procesadas 41300/81444 filas...
# Procesadas 41400/81444 filas...
# Procesadas 41500/81444 filas...
# Procesadas 41600/81444 filas...
# Procesadas 41700/81444 filas...
# Procesadas 41800/81444 filas...
# Procesadas 41900/81444 filas...
# Procesadas 42000/81444 filas...
# Procesadas 42100/81444 filas...
# Procesadas 42200/81444 filas...
# Procesadas 42300/81444 filas...
# Procesadas 42400/81444 filas...
# Procesadas 42500/81444 filas...
# Procesadas 42600/81444 filas...
# Procesadas 42700/81444 filas...
# Procesadas 42800/81444 filas...
# Procesadas 42900/81444 filas...
# Procesadas 43000/81444 filas...
# Procesadas 43100/81444 filas...
# Procesadas 43200/81444 filas...
# Procesadas 43300/81444 filas...
# Procesadas 43400/81444 filas...
# Procesadas 43500/81444 filas...
# Procesadas 43600/81444 filas...
# Procesadas 43700/81444 filas...
# Procesadas 43800/81444 filas...
# Procesadas 43900/81444 filas...
# Procesadas 44000/81444 filas...
# Procesadas 44100/81444 filas...
# Procesadas 44200/81444 filas...
# Procesadas 44300/81444 filas...
# Procesadas 44400/81444 filas...
# Procesadas 44500/81444 filas...
# Procesadas 44600/81444 filas...
# Procesadas 44700/81444 filas...
# Procesadas 44800/81444 filas...
# Procesadas 44900/81444 filas...
# Procesadas 45000/81444 filas...
# Procesadas 45100/81444 filas...
# Procesadas 45200/81444 filas...
# Procesadas 45300/81444 filas...
# Procesadas 45400/81444 filas...
# Procesadas 45500/81444 filas...
# Procesadas 45600/81444 filas...
# Procesadas 45700/81444 filas...
# Procesadas 45800/81444 filas...
# Procesadas 45900/81444 filas...
# Procesadas 46000/81444 filas...
# Procesadas 46100/81444 filas...
# Procesadas 46200/81444 filas...
# Procesadas 46300/81444 filas...
# Procesadas 46400/81444 filas...
# Procesadas 46500/81444 filas...
# Procesadas 46600/81444 filas...
# Procesadas 46700/81444 filas...
# Procesadas 46800/81444 filas...
# Procesadas 46900/81444 filas...
# Procesadas 47000/81444 filas...
# Procesadas 47100/81444 filas...
# Procesadas 47200/81444 filas...
# Procesadas 47300/81444 filas...
# Procesadas 47400/81444 filas...
# Procesadas 47500/81444 filas...
# Procesadas 47600/81444 filas...
# Procesadas 47700/81444 filas...
# Procesadas 47800/81444 filas...
# Procesadas 47900/81444 filas...
# Procesadas 48000/81444 filas...
# Procesadas 48100/81444 filas...
# Procesadas 48200/81444 filas...
# Procesadas 48300/81444 filas...
# Procesadas 48400/81444 filas...
# Procesadas 48500/81444 filas...
# Procesadas 48600/81444 filas...
# Procesadas 48700/81444 filas...
# Procesadas 48800/81444 filas...
# Procesadas 48900/81444 filas...
# Procesadas 49000/81444 filas...
# Procesadas 49100/81444 filas...
# Procesadas 49200/81444 filas...
# Procesadas 49300/81444 filas...
# Procesadas 49400/81444 filas...
# Procesadas 49500/81444 filas...
# Procesadas 49600/81444 filas...
# Procesadas 49700/81444 filas...
# Procesadas 49800/81444 filas...
# Procesadas 49900/81444 filas...
# Procesadas 50000/81444 filas...
# Procesadas 50100/81444 filas...
# Procesadas 50200/81444 filas...
# Procesadas 50300/81444 filas...
# Procesadas 50400/81444 filas...
# Procesadas 50500/81444 filas...
# Procesadas 50600/81444 filas...
# Procesadas 50700/81444 filas...
# Procesadas 50800/81444 filas...
# Procesadas 50900/81444 filas...
# Procesadas 51000/81444 filas...
# Procesadas 51100/81444 filas...
# Procesadas 51200/81444 filas...
# Procesadas 51300/81444 filas...
# Procesadas 51400/81444 filas...
# Procesadas 51500/81444 filas...
# Procesadas 51600/81444 filas...
# Procesadas 51700/81444 filas...
# Procesadas 51800/81444 filas...
# Procesadas 51900/81444 filas...
# Procesadas 52000/81444 filas...
# Procesadas 52100/81444 filas...
# Procesadas 52200/81444 filas...
# Procesadas 52300/81444 filas...
# Procesadas 52400/81444 filas...
# Procesadas 52500/81444 filas...
# Procesadas 52600/81444 filas...
# Procesadas 52700/81444 filas...
# Procesadas 52800/81444 filas...
# Procesadas 52900/81444 filas...
# Procesadas 53000/81444 filas...
# Procesadas 53100/81444 filas...
# Procesadas 53200/81444 filas...
# Procesadas 53300/81444 filas...
# Procesadas 53400/81444 filas...
# Procesadas 53500/81444 filas...
# Procesadas 53600/81444 filas...
# Procesadas 53700/81444 filas...
# Procesadas 53800/81444 filas...
# Procesadas 53900/81444 filas...
# Procesadas 54000/81444 filas...
# Procesadas 54100/81444 filas...
# Procesadas 54200/81444 filas...
# Procesadas 54300/81444 filas...
# Procesadas 54400/81444 filas...
# Procesadas 54500/81444 filas...
# Procesadas 54600/81444 filas...
# Procesadas 54700/81444 filas...
# Procesadas 54800/81444 filas...
# Procesadas 54900/81444 filas...
# Procesadas 55000/81444 filas...
# Procesadas 55100/81444 filas...
# Procesadas 55200/81444 filas...
# Procesadas 55300/81444 filas...
# Procesadas 55400/81444 filas...
# Procesadas 55500/81444 filas...
# Procesadas 55600/81444 filas...
# Procesadas 55700/81444 filas...
# Procesadas 55800/81444 filas...
# Procesadas 55900/81444 filas...
# Procesadas 56000/81444 filas...
# Procesadas 56100/81444 filas...
# Procesadas 56200/81444 filas...
# Procesadas 56300/81444 filas...
# Procesadas 56400/81444 filas...
# Procesadas 56500/81444 filas...
# Procesadas 56600/81444 filas...
# Procesadas 56700/81444 filas...
# Procesadas 56800/81444 filas...
# Procesadas 56900/81444 filas...
# Procesadas 57000/81444 filas...
# Procesadas 57100/81444 filas...
# Procesadas 57200/81444 filas...
# Procesadas 57300/81444 filas...
# Procesadas 57400/81444 filas...
# Procesadas 57500/81444 filas...
# Procesadas 57600/81444 filas...
# Procesadas 57700/81444 filas...
# Procesadas 57800/81444 filas...
# Procesadas 57900/81444 filas...
# Procesadas 58000/81444 filas...
# Procesadas 58100/81444 filas...
# Procesadas 58200/81444 filas...
# Procesadas 58300/81444 filas...
# Procesadas 58400/81444 filas...
# Procesadas 58500/81444 filas...
# Procesadas 58600/81444 filas...
# Procesadas 58700/81444 filas...
# Procesadas 58800/81444 filas...
# Procesadas 58900/81444 filas...
# Procesadas 59000/81444 filas...
# Procesadas 59100/81444 filas...
# Procesadas 59200/81444 filas...
# Procesadas 59300/81444 filas...
# Procesadas 59400/81444 filas...
# Procesadas 59500/81444 filas...
# Procesadas 59600/81444 filas...
# Procesadas 59700/81444 filas...
# Procesadas 59800/81444 filas...
# Procesadas 59900/81444 filas...
# Procesadas 60000/81444 filas...
# Procesadas 60100/81444 filas...
# Procesadas 60200/81444 filas...
# Procesadas 60300/81444 filas...
# Procesadas 60400/81444 filas...
# Procesadas 60500/81444 filas...
# Procesadas 60600/81444 filas...
# Procesadas 60700/81444 filas...
# Procesadas 60800/81444 filas...
# Procesadas 60900/81444 filas...
# Procesadas 61000/81444 filas...
# Procesadas 61100/81444 filas...
# Procesadas 61200/81444 filas...
# Procesadas 61300/81444 filas...
# Procesadas 61400/81444 filas...
# Procesadas 61500/81444 filas...
# Procesadas 61600/81444 filas...
# Procesadas 61700/81444 filas...
# Procesadas 61800/81444 filas...
# Procesadas 61900/81444 filas...
# Procesadas 62000/81444 filas...
# Procesadas 62100/81444 filas...
# Procesadas 62200/81444 filas...
# Procesadas 62300/81444 filas...
# Procesadas 62400/81444 filas...
# Procesadas 62500/81444 filas...
# Procesadas 62600/81444 filas...
# Procesadas 62700/81444 filas...
# Procesadas 62800/81444 filas...
# Procesadas 62900/81444 filas...
# Procesadas 63000/81444 filas...
# Procesadas 63100/81444 filas...
# Procesadas 63200/81444 filas...
# Procesadas 63300/81444 filas...
# Procesadas 63400/81444 filas...
# Procesadas 63500/81444 filas...
# Procesadas 63600/81444 filas...
# Procesadas 63700/81444 filas...
# Procesadas 63800/81444 filas...
# Procesadas 63900/81444 filas...
# Procesadas 64000/81444 filas...
# Procesadas 64100/81444 filas...
# Procesadas 64200/81444 filas...
# Procesadas 64300/81444 filas...
# Procesadas 64400/81444 filas...
# Procesadas 64500/81444 filas...
# Procesadas 64600/81444 filas...
# Procesadas 64700/81444 filas...
# Procesadas 64800/81444 filas...
# Procesadas 64900/81444 filas...
# Procesadas 65000/81444 filas...
# Procesadas 65100/81444 filas...
# Procesadas 65200/81444 filas...
# Procesadas 65300/81444 filas...
# Procesadas 65400/81444 filas...
# Procesadas 65500/81444 filas...
# Procesadas 65600/81444 filas...
# Procesadas 65700/81444 filas...
# Procesadas 65800/81444 filas...
# Procesadas 65900/81444 filas...
# Procesadas 66000/81444 filas...
# Procesadas 66100/81444 filas...
# Procesadas 66200/81444 filas...
# Procesadas 66300/81444 filas...
# Procesadas 66400/81444 filas...
# Procesadas 66500/81444 filas...
# Procesadas 66600/81444 filas...
# Procesadas 66700/81444 filas...
# Procesadas 66800/81444 filas...
# Procesadas 66900/81444 filas...
# Procesadas 67000/81444 filas...
# Procesadas 67100/81444 filas...
# Procesadas 67200/81444 filas...
# Procesadas 67300/81444 filas...
# Procesadas 67400/81444 filas...
# Procesadas 67500/81444 filas...
# Procesadas 67600/81444 filas...
# Procesadas 67700/81444 filas...
# Procesadas 67800/81444 filas...
# Procesadas 67900/81444 filas...
# Procesadas 68000/81444 filas...
# Procesadas 68100/81444 filas...
# Procesadas 68200/81444 filas...
# Procesadas 68300/81444 filas...
# Procesadas 68400/81444 filas...
# Procesadas 68500/81444 filas...
# Procesadas 68600/81444 filas...
# Procesadas 68700/81444 filas...
# Procesadas 68800/81444 filas...
# Procesadas 68900/81444 filas...
# Procesadas 69000/81444 filas...
# Procesadas 69100/81444 filas...
# Procesadas 69200/81444 filas...
# Procesadas 69300/81444 filas...
# Procesadas 69400/81444 filas...
# Procesadas 69500/81444 filas...
# Procesadas 69600/81444 filas...
# Procesadas 69700/81444 filas...
# Procesadas 69800/81444 filas...
# Procesadas 69900/81444 filas...
# Procesadas 70000/81444 filas...
# Procesadas 70100/81444 filas...
# Procesadas 70200/81444 filas...
# Procesadas 70300/81444 filas...
# Procesadas 70400/81444 filas...
# Procesadas 70500/81444 filas...
# Procesadas 70600/81444 filas...
# Procesadas 70700/81444 filas...
# Procesadas 70800/81444 filas...
# Procesadas 70900/81444 filas...
# Procesadas 71000/81444 filas...
# Procesadas 71100/81444 filas...
# Procesadas 71200/81444 filas...
# Procesadas 71300/81444 filas...
# Procesadas 71400/81444 filas...
# Procesadas 71500/81444 filas...
# Procesadas 71600/81444 filas...
# Procesadas 71700/81444 filas...
# Procesadas 71800/81444 filas...
# Procesadas 71900/81444 filas...
# Procesadas 72000/81444 filas...
# Procesadas 72100/81444 filas...
# Procesadas 72200/81444 filas...
# Procesadas 72300/81444 filas...
# Procesadas 72400/81444 filas...
# Procesadas 72500/81444 filas...
# Procesadas 72600/81444 filas...
# Procesadas 72700/81444 filas...
# Procesadas 72800/81444 filas...
# Procesadas 72900/81444 filas...
# Procesadas 73000/81444 filas...
# Procesadas 73100/81444 filas...
# Procesadas 73200/81444 filas...
# Procesadas 73300/81444 filas...
# Procesadas 73400/81444 filas...
# Procesadas 73500/81444 filas...
# Procesadas 73600/81444 filas...
# Procesadas 73700/81444 filas...
# Procesadas 73800/81444 filas...
# Procesadas 73900/81444 filas...
# Procesadas 74000/81444 filas...
# Procesadas 74100/81444 filas...
# Procesadas 74200/81444 filas...
# Procesadas 74300/81444 filas...
# Procesadas 74400/81444 filas...
# Procesadas 74500/81444 filas...
# Procesadas 74600/81444 filas...
# Procesadas 74700/81444 filas...
# Procesadas 74800/81444 filas...
# Procesadas 74900/81444 filas...
# Procesadas 75000/81444 filas...
# Procesadas 75100/81444 filas...
# Procesadas 75200/81444 filas...
# Procesadas 75300/81444 filas...
# Procesadas 75400/81444 filas...
# Procesadas 75500/81444 filas...
# Procesadas 75600/81444 filas...
# Procesadas 75700/81444 filas...
# Procesadas 75800/81444 filas...
# Procesadas 75900/81444 filas...
# Procesadas 76000/81444 filas...
# Procesadas 76100/81444 filas...
# Procesadas 76200/81444 filas...
# Procesadas 76300/81444 filas...
# Procesadas 76400/81444 filas...
# Procesadas 76500/81444 filas...
# Procesadas 76600/81444 filas...
# Procesadas 76700/81444 filas...
# Procesadas 76800/81444 filas...
# Procesadas 76900/81444 filas...
# Procesadas 77000/81444 filas...
# Procesadas 77100/81444 filas...
# Procesadas 77200/81444 filas...
# Procesadas 77300/81444 filas...
# Procesadas 77400/81444 filas...
# Procesadas 77500/81444 filas...
# Procesadas 77600/81444 filas...
# Procesadas 77700/81444 filas...
# Procesadas 77800/81444 filas...
# Procesadas 77900/81444 filas...
# Procesadas 78000/81444 filas...
# Procesadas 78100/81444 filas...
# Procesadas 78200/81444 filas...
# Procesadas 78300/81444 filas...
# Procesadas 78400/81444 filas...
# Procesadas 78500/81444 filas...
# Procesadas 78600/81444 filas...
# Procesadas 78700/81444 filas...
# Procesadas 78800/81444 filas...
# Procesadas 78900/81444 filas...
# Procesadas 79000/81444 filas...
# Procesadas 79100/81444 filas...
# Procesadas 79200/81444 filas...
# Procesadas 79300/81444 filas...
# Procesadas 79400/81444 filas...
# Procesadas 79500/81444 filas...
# Procesadas 79600/81444 filas...
# Procesadas 79700/81444 filas...
# Procesadas 79800/81444 filas...
# Procesadas 79900/81444 filas...
# Procesadas 80000/81444 filas...
# Procesadas 80100/81444 filas...
# Procesadas 80200/81444 filas...
# Procesadas 80300/81444 filas...
# Procesadas 80400/81444 filas...
# Procesadas 80500/81444 filas...
# Procesadas 80600/81444 filas...
# Procesadas 80700/81444 filas...
# Procesadas 80800/81444 filas...
# Procesadas 80900/81444 filas...
# Procesadas 81000/81444 filas...
# Procesadas 81100/81444 filas...
# Procesadas 81200/81444 filas...
# Procesadas 81300/81444 filas...
# Procesadas 81400/81444 filas...
#
# --- RESULTADOS DE LA VERIFICACIÓN ---
# Total de imágenes originales no encontradas: 0
# Total de imágenes generadas no encontradas: 0
# Total de imágenes negativas no encontradas: 0
