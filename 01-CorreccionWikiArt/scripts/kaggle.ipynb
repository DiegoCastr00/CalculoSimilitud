# %% [markdown]
# # Análisis y modificación del dataset

# %%
import numpy as np 
import pandas as pd 

import os

df_classes = pd.read_csv("classes.csv")

# %%
df_classes
# Out:
#                                                 filename           artist  \
# 0      Abstract_Expressionism/aaron-siskind_acolman-1...    aaron siskind
# 1      Abstract_Expressionism/aaron-siskind_chicago-6...    aaron siskind
# 2      Abstract_Expressionism/aaron-siskind_glouceste...    aaron siskind
# 3      Abstract_Expressionism/aaron-siskind_jerome-ar...    aaron siskind
# 4      Abstract_Expressionism/aaron-siskind_kentucky-...    aaron siskind
# ...                                                  ...              ...
# 80037  Impressionism/edgar-degas_portrait-of-mary-cas...      edgar degas
# 80038  High_Renaissance/giorgione_portrait-of-a-venet...        giorgione
# 80039  High_Renaissance/titian_portrait-of-a-venetian...           titian
# 80040  High_Renaissance/pinturicchio_riconciliazione-...     pinturicchio
# 80041  High_Renaissance/luca-signorelli_coriolanus-pe...  luca signorelli
#
#                             genre  \
# 0      ['Abstract Expressionism']
# 1      ['Abstract Expressionism']
# 2      ['Abstract Expressionism']
# 3      ['Abstract Expressionism']
# 4      ['Abstract Expressionism']
# ...                           ...
# 80037           ['Impressionism']
# 80038        ['High Renaissance']
# 80039        ['High Renaissance']
# 80040        ['High Renaissance']
# 80041        ['High Renaissance']
#
#                                              description             phash  \
# 0                                         acolman-1-1955  bebbeb018a7d80a8
# 1                                         chicago-6-1961  d7d0781be51fc00e
# 2                                    gloucester-16a-1944  9f846e5a6c639325
# 3                                    jerome-arizona-1949  a5d691f85ac5e4d0
# 4                                        kentucky-4-1951  880df359e6b11db1
# ...                                                  ...               ...
# 80037                           portrait-of-mary-cassatt  fc8d8c9c49e15365
# 80038           portrait-of-a-venetian-gentleman-1510(2)  fcfc9b330325708c
# 80039                 portrait-of-a-venetian-nobleman(1)  fcfc9b330325708c
# 80040                  riconciliazione-di-coriolano-1509  fef3438ca0d605e1
# 80041  coriolanus-persuaded-by-his-family-to-spare-ro...  fef3438ca0d605e1
#
#        width  height  genre_count            subset
# 0       1922    1382            1             train
# 1       1382    1746            1             train
# 2       1382    1857            1             train
# 3       1382    1849            1             train
# 4       1382    1625            1             train
# ...      ...     ...          ...               ...
# 80037   1382    1756            1  uncertain artist
# 80038   1382    1645            1  uncertain artist
# 80039   1382    1645            1  uncertain artist
# 80040   1382    1412            1  uncertain artist
# 80041   1382    1412            1  uncertain artist
#
# [80042 rows x 9 columns]

# %% [markdown]
# Distribución de los géneros

# %%
genre_counts = df_classes['genre'].value_counts()
count = 1 
for genre, size in genre_counts.items():
    print(f"{count}. Subset: {genre} --- Size: {size}")
    count += 1
# Out:
# 1. Subset: ['Impressionism'] --- Size: 12847
# 2. Subset: ['Realism'] --- Size: 10534
# 3. Subset: ['Romanticism'] --- Size: 6896
# 4. Subset: ['Expressionism'] --- Size: 6280
# 5. Subset: ['Post Impressionism'] --- Size: 6274
# 6. Subset: ['Baroque'] --- Size: 4202
# 7. Subset: ['Symbolism'] --- Size: 4174
# 8. Subset: ['Art Nouveau Modern'] --- Size: 4155
# 9. Subset: ['Abstract Expressionism'] --- Size: 2574
# 10. Subset: ['Northern Renaissance'] --- Size: 2550
# 11. Subset: ['Naive Art Primitivism'] --- Size: 2299
# 12. Subset: ['Rococo'] --- Size: 2070
# 13. Subset: ['Cubism'] --- Size: 2002
# 14. Subset: ['Color Field Painting'] --- Size: 1486
# 15. Subset: ['Pop Art'] --- Size: 1447
# 16. Subset: ['Early Renaissance'] --- Size: 1387
# 17. Subset: ['High Renaissance'] --- Size: 1339
# 18. Subset: ['Mannerism Late Renaissance'] --- Size: 1275
# 19. Subset: ['Minimalism'] --- Size: 1250
# 20. Subset: ['Ukiyo e'] --- Size: 1159
# 21. Subset: ['Fauvism'] --- Size: 747
# 22. Subset: ['Pointillism'] --- Size: 490
# 23. Subset: ['Contemporary Realism'] --- Size: 481
# 24. Subset: ['New Realism'] --- Size: 312
# 25. Subset: ['Synthetic Cubism'] --- Size: 216
# 26. Subset: ['Cubism', 'Expressionism'] --- Size: 139
# 27. Subset: ['Impressionism', 'Realism'] --- Size: 122
# 28. Subset: ['Analytical Cubism'] --- Size: 110
# 29. Subset: ['Fauvism', 'Expressionism'] --- Size: 106
# 30. Subset: ['Symbolism', 'Art Nouveau Modern'] --- Size: 101
# 31. Subset: ['Symbolism', 'Expressionism'] --- Size: 91
# 32. Subset: ['Action painting'] --- Size: 86
# 33. Subset: ['Color Field Painting', 'Abstract Expressionism'] --- Size: 76
# 34. Subset: ['Symbolism', 'Abstract Expressionism'] --- Size: 53
# 35. Subset: ['Minimalism', 'Abstract Expressionism'] --- Size: 40
# 36. Subset: ['Symbolism', 'Romanticism'] --- Size: 39
# 37. Subset: ['Expressionism', 'Post Impressionism'] --- Size: 34
# 38. Subset: ['Minimalism', 'Color Field Painting'] --- Size: 34
# 39. Subset: ['Naive Art Primitivism', 'Expressionism'] --- Size: 32
# 40. Subset: ['Baroque', 'Romanticism'] --- Size: 30
# 41. Subset: ['Cubism', 'Post Impressionism'] --- Size: 30
# 42. Subset: ['Symbolism', 'Realism'] --- Size: 28
# 43. Subset: ['Post Impressionism', 'Art Nouveau Modern'] --- Size: 26
# 44. Subset: ['Naive Art Primitivism', 'Cubism'] --- Size: 24
# 45. Subset: ['Fauvism', 'Cubism'] --- Size: 22
# 46. Subset: ['Naive Art Primitivism', 'Post Impressionism'] --- Size: 21
# 47. Subset: ['Fauvism', 'Post Impressionism'] --- Size: 20
# 48. Subset: ['Symbolism', 'Impressionism'] --- Size: 18
# 49. Subset: ['Rococo', 'Romanticism'] --- Size: 15
# 50. Subset: ['Fauvism', 'Naive Art Primitivism'] --- Size: 15
# 51. Subset: ['Impressionism', 'Impressionism'] --- Size: 14
# 52. Subset: ['Expressionism', 'Art Nouveau Modern'] --- Size: 13
# 53. Subset: ['Symbolism', 'Post Impressionism'] --- Size: 13
# 54. Subset: ['Realism', 'Realism'] --- Size: 12
# 55. Subset: ['Art Nouveau Modern', 'Realism'] --- Size: 12
# 56. Subset: ['Abstract Expressionism', 'Expressionism'] --- Size: 12
# 57. Subset: ['Impressionism', 'Expressionism'] --- Size: 12
# 58. Subset: ['Impressionism', 'Romanticism'] --- Size: 10
# 59. Subset: ['Pop Art', 'Cubism'] --- Size: 10
# 60. Subset: ['Romanticism', 'Art Nouveau Modern'] --- Size: 9
# 61. Subset: ['Impressionism', 'Post Impressionism'] --- Size: 9
# 62. Subset: ['Romanticism', 'Realism'] --- Size: 8
# 63. Subset: ['Pop Art', 'Color Field Painting'] --- Size: 8
# 64. Subset: ['Pop Art', 'Fauvism'] --- Size: 7
# 65. Subset: ['Action painting', 'Abstract Expressionism'] --- Size: 7
# 66. Subset: ['Impressionism', 'Art Nouveau Modern'] --- Size: 7
# 67. Subset: ['Abstract Expressionism', 'Post Impressionism'] --- Size: 6
# 68. Subset: ['Post Impressionism', 'Post Impressionism'] --- Size: 6
# 69. Subset: ['Romanticism', 'Romanticism'] --- Size: 6
# 70. Subset: ['Fauvism', 'Pointillism'] --- Size: 6
# 71. Subset: ['Pop Art', 'Minimalism'] --- Size: 5
# 72. Subset: ['Expressionism', 'Expressionism'] --- Size: 5
# 73. Subset: ['Fauvism', 'Action painting'] --- Size: 5
# 74. Subset: ['Naive Art Primitivism', 'Art Nouveau Modern'] --- Size: 5
# 75. Subset: ['Color Field Painting', 'Color Field Painting'] --- Size: 4
# 76. Subset: ['Ukiyo e', 'Ukiyo e'] --- Size: 4
# 77. Subset: ['Impressionism', 'Pointillism'] --- Size: 4
# 78. Subset: ['Baroque', 'Baroque'] --- Size: 4
# 79. Subset: ['Minimalism', 'Minimalism'] --- Size: 4
# 80. Subset: ['Pointillism', 'Post Impressionism'] --- Size: 4
# 81. Subset: ['Expressionism', 'Realism'] --- Size: 3
# 82. Subset: ['Cubism', 'Abstract Expressionism'] --- Size: 3
# 83. Subset: ['Pointillism', 'Expressionism'] --- Size: 3
# 84. Subset: ['Symbolism', 'Symbolism'] --- Size: 3
# 85. Subset: ['Pop Art', 'Abstract Expressionism'] --- Size: 3
# 86. Subset: ['Mannerism Late Renaissance', 'Mannerism Late Renaissance'] --- Size: 2
# 87. Subset: ['High Renaissance', 'High Renaissance'] --- Size: 2
# 88. Subset: ['Early Renaissance', 'Early Renaissance'] --- Size: 2
# 89. Subset: ['Abstract Expressionism', 'Abstract Expressionism'] --- Size: 2
# 90. Subset: ['Impressionism', 'Fauvism'] --- Size: 2
# 91. Subset: ['Cubism', 'Art Nouveau Modern'] --- Size: 2
# 92. Subset: ['Naive Art Primitivism', 'Abstract Expressionism'] --- Size: 2
# 93. Subset: ['Rococo', 'Rococo'] --- Size: 2
# 94. Subset: ['Symbolism', 'Naive Art Primitivism'] --- Size: 2
# 95. Subset: ['Impressionism', 'Naive Art Primitivism'] --- Size: 1
# 96. Subset: ['Fauvism', 'Abstract Expressionism'] --- Size: 1
# 97. Subset: ['Fauvism', 'Fauvism'] --- Size: 1
# 98. Subset: ['Art Nouveau Modern', 'Art Nouveau Modern'] --- Size: 1
# 99. Subset: ['Post Impressionism', 'Realism'] --- Size: 1
# 100. Subset: ['Pop Art', 'Pointillism'] --- Size: 1
# 101. Subset: ['Pop Art', 'Expressionism'] --- Size: 1
# 102. Subset: ['Pop Art', 'Naive Art Primitivism'] --- Size: 1
# 103. Subset: ['Pointillism', 'Cubism'] --- Size: 1
# 104. Subset: ['Pointillism', 'Abstract Expressionism'] --- Size: 1
# 105. Subset: ['Naive Art Primitivism', 'Naive Art Primitivism'] --- Size: 1
# 106. Subset: ['Northern Renaissance', 'Northern Renaissance'] --- Size: 1
# 107. Subset: ['Naive Art Primitivism', 'Realism'] --- Size: 1
# 108. Subset: ['Symbolism', 'Symbolism', 'Art Nouveau Modern'] --- Size: 1
# 109. Subset: ['Symbolism', 'Fauvism'] --- Size: 1
# 110. Subset: ['Color Field Painting', 'Color Field Painting', 'Color Field Painting'] --- Size: 1
# 111. Subset: ['Cubism', 'Cubism'] --- Size: 1
# 112. Subset: ['New Realism', 'New Realism'] --- Size: 1
# 113. Subset: ['Pointillism', 'Pointillism'] --- Size: 1
# 114. Subset: ['Pointillism', 'Art Nouveau Modern'] --- Size: 1

# %% [markdown]
# ## Función para el filtrado de los géneros

# %%
import pandas as pd
import ast

def filter_by_genres(df, target_genres):
    """
    Filtra un DataFrame buscando filas donde la columna 'genre' coincida exactamente con los géneros objetivo.
    
    Parameters:
    df (pandas.DataFrame): DataFrame con una columna 'genre' que contiene listas de géneros como strings
    target_genres (list): Lista de géneros a buscar
    
    Returns:
    pandas.DataFrame: DataFrame filtrado con las filas que coinciden exactamente
    """    
    
    def normalize_genres(genre_str):
        try:
            genres = ast.literal_eval(genre_str)
            return sorted(list(genres))
        except:
            return []
    
    target_genres = sorted(list(target_genres))
    
    # Aplica la función de normalización a la columna 'genre'
    df['normalized_genres'] = df['genre'].apply(normalize_genres)
    
    # Filtra las filas donde los géneros normalizados coinciden exactamente
    filtered_df = df[df['normalized_genres'].apply(lambda x: x == target_genres)]
    
    # Elimina la columna temporal de géneros normalizados
    filtered_df = filtered_df.drop('normalized_genres', axis=1)
    
    return filtered_df

# %% [markdown]
# Filtrado de búsqueda por géneros

# %%
# pd.set_option('display.max_columns', None)  # Muestra todas las columnas
# pd.set_option('display.max_rows', None)     # Muestra todas las filas
# pd.set_option('display.width', None)        # No limita el ancho de la pantalla
# pd.set_option('display.max_colwidth', None) # Muestra el contenido completo de cada celda

generos_buscar = ['Expressionism', 'Realism'] 
resultado = filter_by_genres(df_classes, generos_buscar)
resultado
# Out:
#                                                 filename           artist  \
# 15310  Expressionism/gerard-sekoto_the-proud-father-m...    gerard sekoto
# 15556       Expressionism/horia-bernea_unknown-title.jpg     horia bernea
# 16671  Expressionism/martiros-saryan_from-the-artist-...  martiros saryan
#
#                               genre  \
# 15310  ['Expressionism', 'Realism']
# 15556  ['Expressionism', 'Realism']
# 16671  ['Expressionism', 'Realism']
#
#                                              description             phash  \
# 15310  the-proud-father-manakedi-naky-on-bernard-seko...  ebcd9da52c901372
# 15556                                      unknown-title  8d943a7ae0611f3e
# 16671  from-the-artist-s-life-portrait-of-lusik-sarya...  901eade0c5934fa7
#
#        width  height  genre_count subset
# 15310   1382    1867            2  train
# 15556   1384    1382            2  train
# 16671   1771    1382            2  train

# %% [markdown]
# ## Compactación de los géneros a los principales

# %%
import pandas as pd
import ast

def simplify_first_genre(df, column_name='genre'):
    """
    Extrae el primer género de una columna que contiene strings de listas
    y lo devuelve como un string simple.
    
    Parameters:
    df (pandas.DataFrame): DataFrame con la columna de géneros
    column_name (str): Nombre de la columna que contiene los géneros
    
    Returns:
    pandas.DataFrame: DataFrame con la columna de géneros simplificada
    """
    def extract_first_genre(genre_str):
        try:
            # Convierte el string de la lista a una lista real
            genres = ast.literal_eval(genre_str)
            # Toma el primer género si existe
            return genres[0] if genres else ''
        except:
            return ''
    
    # Crea una copia del DataFrame para no modificar el original
    df_copy = df.copy()
    
    # Aplica la transformación
    df_copy[column_name] = df_copy[column_name].apply(extract_first_genre)
    
    return df_copy

# %%
# Simplificamos los generos
df_genre = simplify_first_genre(df_classes)
#Eliminamos columnas inecesarias
df_genre = df_genre.drop(columns=['genre_count','width','height','normalized_genres'])
df_genre
# Out:
#                                                 filename           artist  \
# 0      Abstract_Expressionism/aaron-siskind_acolman-1...    aaron siskind
# 1      Abstract_Expressionism/aaron-siskind_chicago-6...    aaron siskind
# 2      Abstract_Expressionism/aaron-siskind_glouceste...    aaron siskind
# 3      Abstract_Expressionism/aaron-siskind_jerome-ar...    aaron siskind
# 4      Abstract_Expressionism/aaron-siskind_kentucky-...    aaron siskind
# ...                                                  ...              ...
# 80037  Impressionism/edgar-degas_portrait-of-mary-cas...      edgar degas
# 80038  High_Renaissance/giorgione_portrait-of-a-venet...        giorgione
# 80039  High_Renaissance/titian_portrait-of-a-venetian...           titian
# 80040  High_Renaissance/pinturicchio_riconciliazione-...     pinturicchio
# 80041  High_Renaissance/luca-signorelli_coriolanus-pe...  luca signorelli
#
#                         genre  \
# 0      Abstract Expressionism
# 1      Abstract Expressionism
# 2      Abstract Expressionism
# 3      Abstract Expressionism
# 4      Abstract Expressionism
# ...                       ...
# 80037           Impressionism
# 80038        High Renaissance
# 80039        High Renaissance
# 80040        High Renaissance
# 80041        High Renaissance
#
#                                              description  width  height  \
# 0                                         acolman-1-1955   1922    1382
# 1                                         chicago-6-1961   1382    1746
# 2                                    gloucester-16a-1944   1382    1857
# 3                                    jerome-arizona-1949   1382    1849
# 4                                        kentucky-4-1951   1382    1625
# ...                                                  ...    ...     ...
# 80037                           portrait-of-mary-cassatt   1382    1756
# 80038           portrait-of-a-venetian-gentleman-1510(2)   1382    1645
# 80039                 portrait-of-a-venetian-nobleman(1)   1382    1645
# 80040                  riconciliazione-di-coriolano-1509   1382    1412
# 80041  coriolanus-persuaded-by-his-family-to-spare-ro...   1382    1412
#
#                  subset
# 0                 train
# 1                 train
# 2                 train
# 3                 train
# 4                 train
# ...                 ...
# 80037  uncertain artist
# 80038  uncertain artist
# 80039  uncertain artist
# 80040  uncertain artist
# 80041  uncertain artist
#
# [80042 rows x 7 columns]

# %%
genre_counts = df_genre['genre'].value_counts()
count = 1 
for genre, size in genre_counts.items():
    print(f"{count}. Subset: {genre} --- Size: {size}")
    count += 1
# Out:
# 1. Subset: Impressionism --- Size: 13028
# 2. Subset: Realism --- Size: 10546
# 3. Subset: Romanticism --- Size: 6919
# 4. Subset: Expressionism --- Size: 6335
# 5. Subset: Post Impressionism --- Size: 6307
# 6. Subset: Symbolism --- Size: 4524
# 7. Subset: Baroque --- Size: 4236
# 8. Subset: Art Nouveau Modern --- Size: 4168
# 9. Subset: Abstract Expressionism --- Size: 2594
# 10. Subset: Northern Renaissance --- Size: 2551
# 11. Subset: Naive Art Primitivism --- Size: 2385
# 12. Subset: Cubism --- Size: 2177
# 13. Subset: Rococo --- Size: 2087
# 14. Subset: Color Field Painting --- Size: 1567
# 15. Subset: Pop Art --- Size: 1483
# 16. Subset: Early Renaissance --- Size: 1389
# 17. Subset: High Renaissance --- Size: 1341
# 18. Subset: Minimalism --- Size: 1328
# 19. Subset: Mannerism Late Renaissance --- Size: 1277
# 20. Subset: Ukiyo e --- Size: 1163
# 21. Subset: Fauvism --- Size: 923
# 22. Subset: Pointillism --- Size: 501
# 23. Subset: Contemporary Realism --- Size: 481
# 24. Subset: New Realism --- Size: 313
# 25. Subset: Synthetic Cubism --- Size: 216
# 26. Subset: Analytical Cubism --- Size: 110
# 27. Subset: Action painting --- Size: 93

# %%
subset_counts = df_genre['subset'].value_counts()
for subset, count in subset_counts.items():
    print(f"Subset: {subset}, Size: {count}")
# Out:
# Subset: train, Size: 63998
# Subset: test, Size: 16000
# Subset: uncertain artist, Size: 44

# %%
import pandas as pd

def simplify_subset(df, column_name='subset'):
    """
    Convierte los registros con subset 'uncertain artist' a 'test'
    
    Parameters:
    df (pandas.DataFrame): DataFrame con la columna subset
    column_name (str): Nombre de la columna que contiene los subsets
    
    Returns:
    pandas.DataFrame: DataFrame con la columna subset modificada
    """
    # Crea una copia del DataFrame para no modificar el original
    df_copy = df.copy()
    
    # Reemplaza 'uncertain artist' con 'test'
    df_copy[column_name] = df_copy[column_name].replace('uncertain artist', 'test')
    
    return df_copy

# %%
df_subset = simplify_subset(df_genre)

print("\nNueva distribución de subsets:")
subset_counts = df_subset['subset'].value_counts()
for subset, count in subset_counts.items():
    print(f"Subset: {subset}, Size: {count}")
# Out:
# Nueva distribución de subsets:
# Subset: train, Size: 63998
# Subset: test, Size: 16044

# %%
# import pandas as pd
# import numpy as np
# from matplotlib import pyplot as plt
# import seaborn as sns

# def analyze_image_dimensions(df_copy, width_col='width', height_col='height'):
#     """
#     Realiza un análisis completo de las dimensiones de las imágenes.
    
#     Parameters:
#     df (pandas.DataFrame): DataFrame con columnas de width y height
#     width_col (str): Nombre de la columna de ancho
#     height_col (str): Nombre de la columna de altura
    
#     Returns:
#     dict: Diccionario con estadísticas relevantes
#     """
#     df = df_copy.copy()
#     # Calcular estadísticas básicas
#     stats = {
#         'width_stats': df[width_col].describe(),
#         'height_stats': df[height_col].describe(),
#         'aspect_ratios': df[width_col] / df[height_col]
#     }
    
#     # Calcular área de cada imagen
#     df['area'] = df[width_col] * df[height_col]
#     stats['area_stats'] = df['area'].describe()
    
#     # Encontrar dimensiones más comunes
#     common_dimensions = df.groupby([width_col, height_col]).size().sort_values(ascending=False).head(10)
#     stats['common_dimensions'] = common_dimensions
    
#     # Crear visualizaciones
#     plt.figure(figsize=(15, 10))
    
#     # Subplot 1: Scatter plot de width vs height
#     plt.subplot(2, 2, 1)
#     plt.scatter(df[width_col], df[height_col], alpha=0.1)
#     plt.xlabel('Width')
#     plt.ylabel('Height')
#     plt.title('Width vs Height Distribution')
    
#     # Subplot 2: Histograma de aspect ratios
#     plt.subplot(2, 2, 2)
#     sns.histplot(data=stats['aspect_ratios'].clip(0, 3), bins=50)
#     plt.title('Aspect Ratio Distribution (clipped at 3)')
#     plt.xlabel('Aspect Ratio (width/height)')
    
#     # Subplot 3: Distribución de anchos
#     plt.subplot(2, 2, 3)
#     sns.boxplot(x=df[width_col])
#     plt.title('Width Distribution')
    
#     # Subplot 4: Distribución de alturas
#     plt.subplot(2, 2, 4)
#     sns.boxplot(x=df[height_col])
#     plt.title('Height Distribution')
    
#     plt.tight_layout()
#     plt.show()
    
#     # Imprimir resumen de estadísticas
#     print("\n=== ANÁLISIS DE DIMENSIONES DE IMÁGENES ===")
    
#     print("\n1. Estadísticas de Ancho (píxeles):")
#     print(stats['width_stats'])
    
#     print("\n2. Estadísticas de Alto (píxeles):")
#     print(stats['height_stats'])
    
#     print("\n3. Estadísticas de Área (píxeles cuadrados):")
#     print(stats['area_stats'])
    
#     print("\n4. Dimensiones más comunes (width x height):")
#     print(common_dimensions)
    
#     print("\n5. Recomendaciones para resize:")
#     width_median = stats['width_stats']['50%']
#     height_median = stats['height_stats']['50%']
#     width_mean = stats['width_stats']['mean']
#     height_mean = stats['height_stats']['mean']
    
#     print(f"\nDimensiones basadas en la mediana: {width_median:.0f}x{height_median:.0f}")
#     print(f"Dimensiones basadas en la media: {width_mean:.0f}x{height_mean:.0f}")
    


#     return stats

# %%
# analyze_image_dimensions(df_subset)

# %% [markdown]
# Guardar Dataframe

# %%
df_subset
# Out:
#                                                 filename           artist  \
# 0      Abstract_Expressionism/aaron-siskind_acolman-1...    aaron siskind
# 1      Abstract_Expressionism/aaron-siskind_chicago-6...    aaron siskind
# 2      Abstract_Expressionism/aaron-siskind_glouceste...    aaron siskind
# 3      Abstract_Expressionism/aaron-siskind_jerome-ar...    aaron siskind
# 4      Abstract_Expressionism/aaron-siskind_kentucky-...    aaron siskind
# ...                                                  ...              ...
# 80037  Impressionism/edgar-degas_portrait-of-mary-cas...      edgar degas
# 80038  High_Renaissance/giorgione_portrait-of-a-venet...        giorgione
# 80039  High_Renaissance/titian_portrait-of-a-venetian...           titian
# 80040  High_Renaissance/pinturicchio_riconciliazione-...     pinturicchio
# 80041  High_Renaissance/luca-signorelli_coriolanus-pe...  luca signorelli
#
#                         genre  \
# 0      Abstract Expressionism
# 1      Abstract Expressionism
# 2      Abstract Expressionism
# 3      Abstract Expressionism
# 4      Abstract Expressionism
# ...                       ...
# 80037           Impressionism
# 80038        High Renaissance
# 80039        High Renaissance
# 80040        High Renaissance
# 80041        High Renaissance
#
#                                              description  width  height subset
# 0                                         acolman-1-1955   1922    1382  train
# 1                                         chicago-6-1961   1382    1746  train
# 2                                    gloucester-16a-1944   1382    1857  train
# 3                                    jerome-arizona-1949   1382    1849  train
# 4                                        kentucky-4-1951   1382    1625  train
# ...                                                  ...    ...     ...    ...
# 80037                           portrait-of-mary-cassatt   1382    1756   test
# 80038           portrait-of-a-venetian-gentleman-1510(2)   1382    1645   test
# 80039                 portrait-of-a-venetian-nobleman(1)   1382    1645   test
# 80040                  riconciliazione-di-coriolano-1509   1382    1412   test
# 80041  coriolanus-persuaded-by-his-family-to-spare-ro...   1382    1412   test
#
# [80042 rows x 7 columns]

# %%
# df_subset.to_csv('dataset.csv', index=False)
